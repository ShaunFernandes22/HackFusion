# %%
#Install DeepFace Library
# !pip install deepface -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.26.4 which is incompatible.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 1.26.4 which is incompatible.

# %%
#Import DeepFace, CV2 and Matplotlib libraries
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
#Read and display image through CV2
check_img = cv2.imread('WIN_20240317_11_17_27_Pro.jpg')
plt.imshow(check_img[:, :, ::-1])

# %%
#DeepFace analyse the uploaded image
analyze_face = DeepFace.analyze(check_img,actions=['emotion'])
analyze_face
# Out:
# [{'emotion': {'angry': 3.2432409073854034,
#    'disgust': 0.0002162954516962952,
#    'fear': 37.21233828141322,
#    'happy': 6.815180588673388,
#    'sad': 31.05448073473458,
#    'surprise': 0.04623010739099875,
#    'neutral': 21.62831405569995},
#   'dominant_emotion': 'fear',
#   'region': {'x': 531,
#    'y': 228,
#    'w': 277,
#    'h': 277,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.98}]

# %%
# !pip install gradio_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/298.2 kB ? eta -:--:--
#      ━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/298.2 kB 2.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# ...

# %%
from gradio_client import Client

client = Client("https://huggingfaceh4-falcon-chat.hf.space/")
result = client.predict(
				"Howdy!",	# str  in 'Click on any example and press Enter in the input textbox!' Dataset component
				fn_index=0
)
print(result)
# Out:
# Loaded as API: https://huggingfaceh4-falcon-chat.hf.space/ ✔
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/gradio_client/client.py in _predict(*data)
#     830             try:
# --> 831                 output = result["data"]
#     832             except KeyError as ke:
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-27a7522d1083> in <cell line: 4>()
#       2
#       3 client = Client("https://huggingfaceh4-falcon-chat.hf.space/")
# ----> 4 result = client.predict(
#       5                                 "Howdy!",       # str  in 'Click on any example and press Enter in the input textbox!' Dataset component
#       6                                 fn_index=0
#
# ...

# %%
# !pip install fastapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from fastapi import FastAPI, File, UploadFile
from fastapi.middleware.cors import CORSMiddleware

app = FastAPI()
app.add_middleware(
CORSMiddleware,
allow_origins=["*"],
allow_credentials=True,
allow_methods=["*"],
allow_headers=["*"],
)

# %%
# !pip install python-multipart
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/45.7 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.2 MB/s eta 0:00:00
# ...

# %%
# !pip install openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/792.9 kB ? eta -:--:--
#      ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/792.9 kB 3.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━ 532.5/792.9 kB 7.6 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.9/792.9 kB 7.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.7 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=796907 sha256=bf8447e930f03f83708837be3834a3d72f9ed1666d09689a0b9586e4df57cbc7
#   Stored in directory: /root/.cache/pip/wheels/b2/13/5f/fe8245f6dc59df505879da4b2129932e342f02a80e6b87f27d
# Successfully built openai-whisper
# ...

# %%
import whisper

# %%
voice_model = whisper.load_model("large-v2")
# Out:
# 100%|██████████████████████████████████████| 2.87G/2.87G [00:20<00:00, 154MiB/s]

# %%
import os, uuid

# %%
# !pip install uvicorn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import uvicorn

# %%
# !pip install pyngrok nest_asyncio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.7/698.7 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-6.1.0-py3-none-any.whl size=20583 sha256=ebc1fcd1319cb8c24d0e9e41281050ed2145d370c1e5614fafe7eb03c535e60f
#   Stored in directory: /root/.cache/pip/wheels/d8/2d/7a/97a039fca211fa789bffad50ff97dca13c01e9b83e8879f503
# Successfully built pyngrok
# ...

# %%
from pyngrok import ngrok

# %%
import nest_asyncio

# %%
# !ngrok config add-authtoken 2UZfV5qD30hnprHEMPkfF7h6BV6_89mYVBBsPm7AvXB7Arxx9
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
if __name__=="__main__":
    ngrok_tunnel = ngrok.connect(8000)
    print('Public URL:', ngrok_tunnel.public_url)
    nest_asyncio.apply()
    uvicorn.run(app,port=8000)
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-09-15T14:34:08+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# Public URL: https://4ca4-34-125-138-159.ngrok-free.app
# INFO:     Started server process [382]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     139.5.239.162:0 - "POST /transcribe/ HTTP/1.1" 400 Bad Request
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [382]

# %%
# !pip install speechbrain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/553.8 kB ? eta -:--:--
#      ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/553.8 kB 3.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 481.3/553.8 kB 6.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.8/553.8 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 15.1 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 18.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.1 MB/s eta 0:00:00

# %%
from speechbrain.pretrained.interfaces import foreign_class

# %%
classifier = foreign_class(source="speechbrain/emotion-recognition-wav2vec2-IEMOCAP", pymodule_file="custom_interface.py", classname="CustomEncoderWav2vec2Classifier")
out_prob, score, index, text_lab = classifier.classify_file("/content/angry.wave")
print(text_lab)
# Out:
# WARNING:speechbrain.lobes.models.huggingface_wav2vec:speechbrain.lobes.models.huggingface_wav2vec - wav2vec 2.0 is frozen.
# ['ang']

# %%
if __name__=="__main__":
    ngrok_tunnel = ngrok.connect(8000)
    print('Public URL:', ngrok_tunnel.public_url)
    nest_asyncio.apply()
    uvicorn.run(app,port=8000)
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-09-16T01:16:52+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# Public URL: https://f0f3-35-227-67-163.ngrok-free.app
# INFO:     Started server process [190]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     139.5.239.162:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     139.5.239.162:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     139.5.239.162:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     139.5.239.162:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     139.5.239.162:0 - "POST /speech-emotion/ HTTP/1.1" 400 Bad Request
# INFO:     139.5.239.162:0 - "POST /text-emotion/?input=meow HTTP/1.1" 200 OK
# INFO:     139.5.239.162:0 - "GET / HTTP/1.1" 404 Not Found
# ...
